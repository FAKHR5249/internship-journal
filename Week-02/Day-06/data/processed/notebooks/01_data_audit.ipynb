# %%
# NYC Taxi Data Audit

## Week 3 Advanced Regression Benchmark

### Objectives

- Load processed dataset
- Inspect dataset
- Check missing values
- Check duplicates
- Check invalid records
- Analyze target variable

# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", None)

print("Libraries Loaded Successfully")

# %%
DATA_PATH = "../data/processed/featured_taxi_data.parquet"

df = pd.read_parquet(DATA_PATH)

print("Dataset Loaded Successfully")

# %% [markdown]
# ## Dataset Shape

# %%
print("Rows :", df.shape[0])
print("Columns :", df.shape[1])

# %% [markdown]
# ## First Five Rows

# %%
df.head()

# %% [markdown]
# ## Dataset Information

# %%
df.info()

# %% [markdown]
# ## Statistical Summary

# %%
df.describe(include="all")

# %% [markdown]
# ## Missing Values

# %%
missing = df.isnull().sum()

missing[missing > 0].sort_values(ascending=False)

# %% [markdown]
# ## Duplicate Records

# %%
duplicates = df.duplicated().sum()

print("Duplicate Rows :", duplicates)

# %% [markdown]
# ## Data Types

# %%
df.dtypes

# %% [markdown]
# ## Target Variable Statistics

# %%
df["trip_duration_minutes"].describe()

# %% [markdown]
# ## Invalid Trip Durations

# %%
negative_duration = (df["trip_duration_minutes"] < 0).sum()

zero_duration = (df["trip_duration_minutes"] == 0).sum()

print("Negative Duration :", negative_duration)

print("Zero Duration :", zero_duration)

# %% [markdown]
# ## Invalid Passenger Count

# %%
(df["passenger_count"] <= 0).sum()

# %% [markdown]
# ## Invalid Trip Distance

# %%
(df["trip_distance"] <= 0).sum()

# %% [markdown]
# ## Summary

# %% [markdown]
# ### Data Audit Conclusion
#
# - Dataset loaded successfully.
# - Data types verified.
# - Missing values inspected.
# - Duplicate records checked.
# - Invalid passenger counts reviewed.
# - Invalid trip durations checked.
# - Target variable verified.
# - Dataset is ready for exploratory data analysis.
